# %% [markdown]
# # Visualizations

# %% [markdown]
# - The standard visualization package of python is `matplotlib`, which works fine, is very customizable, but doesn't always looks too great.
# - `Seaborn` is another package that is built on top of `matplotlib` and looks a little better.
# - `Vincent` is another package you might want to try out.

# %% [markdown]
# ## matplotlib

# %% [markdown]
# - The standard visualization package of python is `matplotlib`.
# - We use the magic command `%matplotlib inline` so that images are embedded in the notebook.
# - See the <a href="http://matplotlib.org/users/pyplot_tutorial.html" target="_blank">pyplot tutorial</a> for a quick Getting Started guide.

# %%
from matplotlib import pyplot as plt  
# %matplotlib inline

# %% [markdown]
# - The most common function of matplotlib is `plot`.
# - Type `?plt.plot` to see the doc string.

# %%
xx = range(10)
yy = [x ** 2 + 1 for x in xx]
plt.plot(xx, yy, 'r:')  # 'r' = red, and ':' = dotted line

# %% [markdown]
# Almost everything is customizable in `matplotlib`.

# %%
plt.title("Hello, world!")
plt.xlabel("x-axis"), plt.ylabel("y-axis")
plt.xlim(0, 5), plt.ylim(0, 70)
plt.plot(xx, yy, 'bs-', label="parabole")
plt.plot(range(6), range(6), 'y*:', markersize=10, label="straight line")
f = plt.legend()
# I often write `f = ` on the last line to surpress the output `<matplotlib.lines.Line2D at 0x10c750390>`

# %% [markdown]
# ## Pandas plots

# %% [markdown]
# Pandas is built on top of `matplotlib` and has several functions built-in.
#
# - If you haven't done so already, download the
# <a href="http://seanlahman.com/files/database/lahman-csv_2014-02-14.zip">Lahman Baseball dataset</a>.
# - Note that you can find information about the meaning of the columns and the data in the `readme.txt` file.
# - Load the `batting` dataset.

# %%
# Specify the correct path to the folder in `path_to_data`.
path_to_data = '/Users/ruben/Downloads/lahman-csv_2014-02-14/'

# %%
import pandas as pd
batting = pd.read_csv(path_to_data + 'Batting.csv')

# %% [markdown]
# - Plot trend of average number of homeruns per year

# %%
batting.groupby('yearID').HR.mean().plot()
plt.title("Average # of homeruns by year")

# %%
# We can also plot multiple features at ones in one plot
# Note the `f = ` on the last line, to surpress the output `<matplotlib.text.Text at 0x10da8fcd0>`
batting[['playerID', 'yearID', 'HR', 'RBI']].groupby('yearID').mean().plot()
f = plt.title("Average # of homeruns and runs batted in by year")

# %%
# What is the distributions of homeruns per player per year?
f = batting.HR.hist()

# %%
f = batting.HR.hist(bins=20)

# %%
f = batting.HR.hist(bins=range(30))

# %%
plt.title('Homeruns vs Runs Batted In per player')
plt.xlabel('Runs Batted In'), plt.xlabel('Homeruns')
plt.xlim(0, 200), plt.ylim(0, 80)
f = plt.scatter(batting.RBI, batting.HR, linewidth=0, alpha=.1)

# %% [markdown]
# ## seaborn

# %% [markdown]
# - Seaborn is a Python visualization library based on matplotlib. It provides a high-level interface for drawing attractive statistical graphics.
# - Install seaborn by typing `pip install seaborn` on the command line.
# - Simply importing `seaborn` already impacts your visualizations.

# %%
import seaborn as sb

# %%
batting[['playerID', 'yearID', 'HR', 'RBI']].groupby('yearID').mean().plot()
f = plt.title("Average # of homeruns and runs batted in by year")

# %%
batting[batting['AB'] > 200]['HR'].hist()

# %% [markdown]
# Seaborn also has its own functions.

# %%
f = sb.boxplot(batting[batting['AB'] > 200][['HR', 'RBI']])

# %%
f = sb.violinplot(batting[batting['AB'] > 200][['HR']])

# %%
# filter only for # At Bats > 200
data = batting[batting['AB'] > 200]  
# look at last 10 years
data = data[data['yearID'] > 2005]
# look at teams with highest # or homeruns on average
top_teams = data[['teamID', 'HR']].groupby('teamID').mean().sort('HR', ascending=False)
data = data[data.teamID.isin(top_teams[:10].index)]
# print top_teams[:10]

# Homeruns per year, for the best teams individually
f = sb.factorplot(x='yearID', y='HR', col='teamID', col_wrap=5, data=data)

# %%
# What does the following code do?
g = sb.FacetGrid(data, col='yearID', col_wrap=4)
f = g.map(plt.hist, 'HR')

# %% [markdown]
# ### Vincent

# %% [markdown]
# - Vincent combines the data capabilities of Python and Pandas with the visualization capabilities of JavaScript, D3 and Vega.
# - Install Vincent by typing `pip install vincent` on the command line.
# - Also see
# <a href="http://vincent.readthedocs.org/en/latest/quickstart.html" target="_blank">Quik start guide</a>

# %%
import vincent
reload(vincent)
vincent.initialize_notebook()
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>

# %%
# Load salaries data file
salaries = pd.read_csv(path_to_data + 'salaries.csv')
team_salary = salaries[salaries['yearID'] == 2013].groupby('teamID')[['salary']].sum()

# %%
salary_plot = vincent.Bar(team_salary)
salary_plot.axis_titles(x='Team', y='Salary')
# Out:
# <div id="visb4ebe692efcb46198cb882c4e3a29e41"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Team", "type": "x"}, {"scale": "y", "title": "Salary", "type": "y"}], "data": [{"name": "table", "values": [{"col": "salary", "idx": "ARI", "val": 90132000}, {"col": "salary", "idx": "ATL", "val": 87871525}, {"col": "salary", "idx": "BAL", "val": 84393333}, {"col": "salary", "idx": "BOS", "val": 151530000}, {"col": "salary", "idx": "CHA", "val": 120065277}, {"col": "salary", "idx": "CHN", "val": 100567726}, {"col": "salary", "idx": "CIN", "val": 106404462}, {"col": "salary", "idx": "CLE", "val": 75771800}, {"col": "salary", "idx": "COL", "val": 74409071}, {"col": "salary", "idx": "DET", "val": 145989500}, {"col": "salary", "idx": "HOU", "val": 17890700}, {"col": "salary", "idx": "KCA", "val": 80091725}, {"col": "salary", "idx": "LAA", "val": 124174750}, {"col": "salary", "idx": "LAN", "val": 223362196}, {"col": "salary", "idx": "MIA", "val": 33601900}, {"col": "salary", "idx": "MIL", "val": 76947033}, {"col": "salary", "idx": "MIN", "val": 75337500}, {"col": "salary", "idx": "NYA", "val": 231978886}, {"col": "salary", "idx": "NYN", "val": 49448346}, {"col": "salary", "idx": "OAK", "val": 60132500}, {"col": "salary", "idx": "PHI", "val": 169863189}, {"col": "salary", "idx": "PIT", "val": 77062000}, {"col": "salary", "idx": "SDN", "val": 65585500}, {"col": "salary", "idx": "SEA", "val": 74005043}, {"col": "salary", "idx": "SFN", "val": 140180334}, {"col": "salary", "idx": "SLN", "val": 92260110}, {"col": "salary", "idx": "TBA", "val": 52955272}, {"col": "salary", "idx": "TEX", "val": 112522600}, {"col": "salary", "idx": "TOR", "val": 126288100}, {"col": "salary", "idx": "WAS", "val": 113703270}]}, {"name": "stats", "source": "table", "transform": [{"keys": ["data.idx"], "type": "facet"}, {"type": "stats", "value": "data.val"}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table", "transform": [{"keys": ["data.col"], "type": "facet"}, {"height": "data.val", "point": "data.idx", "type": "stack"}]}, "marks": [{"properties": {"enter": {"fill": {"field": "data.col", "scale": "color"}, "width": {"band": true, "offset": -1, "scale": "x"}, "x": {"field": "data.idx", "scale": "x"}, "y": {"field": "y", "scale": "y"}, "y2": {"field": "y2", "scale": "y"}}}, "type": "rect"}], "type": "group"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "x", "range": "width", "type": "ordinal", "zero": false}, {"domain": {"data": "stats", "field": "sum"}, "name": "y", "nice": true, "range": "height"}, {"domain": {"data": "table", "field": "data.col"}, "name": "color", "range": "category20", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#visb4ebe692efcb46198cb882c4e3a29e41"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>

# %%
year_salary = salaries.groupby('yearID')[['salary']].sum()
year_salary.index = pd.to_datetime(year_salary.index, format="%Y")
vincent.Scatter(year_salary)
# Out:
# <div id="visafe08841d60d4c1ab2f9db0eb281331e"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "type": "x"}, {"scale": "y", "type": "y"}], "data": [{"name": "table", "values": [{"col": "salary", "idx": 473403600000, "val": 261964696}, {"col": "salary", "idx": 504939600000, "val": 307854518}, {"col": "salary", "idx": 536475600000, "val": 272575375}, {"col": "salary", "idx": 568011600000, "val": 300452424}, {"col": "salary", "idx": 599634000000, "val": 359995711}, {"col": "salary", "idx": 631170000000, "val": 443881193}, {"col": "salary", "idx": 662706000000, "val": 613048418}, {"col": "salary", "idx": 694242000000, "val": 805543323}, {"col": "salary", "idx": 725864400000, "val": 901740134}, {"col": "salary", "idx": 757400400000, "val": 927836287}, {"col": "salary", "idx": 788936400000, "val": 951469367}, {"col": "salary", "idx": 820472400000, "val": 956983550}, {"col": "salary", "idx": 852094800000, "val": 1127285885}, {"col": "salary", "idx": 883630800000, "val": 1278282871}, {"col": "salary", "idx": 915166800000, "val": 1494228750}, {"col": "salary", "idx": 946702800000, "val": 1666135102}, {"col": "salary", "idx": 978325200000, "val": 1960663313}, {"col": "salary", "idx": 1009861200000, "val": 2024077522}, {"col": "salary", "idx": 1041397200000, "val": 2128262128}, {"col": "salary", "idx": 1072933200000, "val": 2070665943}, {"col": "salary", "idx": 1104555600000, "val": 2188713398}, {"col": "salary", "idx": 1136091600000, "val": 2321472617}, {"col": "salary", "idx": 1167627600000, "val": 2476688987}, {"col": "salary", "idx": 1199163600000, "val": 2684858670}, {"col": "salary", "idx": 1230786000000, "val": 2664726994}, {"col": "salary", "idx": 1262322000000, "val": 2721359865}, {"col": "salary", "idx": 1293858000000, "val": 2784505291}, {"col": "salary", "idx": 1325394000000, "val": 2932741192}, {"col": "salary", "idx": 1357016400000, "val": 3034525648}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table", "transform": [{"keys": ["data.col"], "type": "facet"}]}, "marks": [{"properties": {"enter": {"fill": {"field": "data.col", "scale": "color"}, "size": {"value": 100}, "x": {"field": "data.idx", "scale": "x"}, "y": {"field": "data.val", "scale": "y"}}}, "type": "symbol"}], "type": "group"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "x", "range": "width", "type": "time"}, {"domain": {"data": "table", "field": "data.val"}, "name": "y", "nice": true, "range": "height"}, {"domain": {"data": "table", "field": "data.col"}, "name": "color", "range": "category20", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#visafe08841d60d4c1ab2f9db0eb281331e"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>

# %%
team_year_salary = pd.pivot_table(salaries, index='yearID', columns='teamID', values='salary', aggfunc='sum')
f = vincent.StackedBar(team_year_salary).legend(title='Teams')
f.width, f.height = 800, 500
f
# Out:
# <div id="vis95e1ba7f1e5c4ea68f7a7d537b74fb5e"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "type": "x"}, {"scale": "y", "type": "y"}], "data": [{"name": "table", "values": [{"col": "ANA", "idx": 1985, "val": NaN}, {"col": "ARI", "idx": 1985, "val": NaN}, {"col": "ATL", "idx": 1985, "val": 14807000.0}, {"col": "BAL", "idx": 1985, "val": 11560712.0}, {"col": "BOS", "idx": 1985, "val": 10897560.0}, {"col": "CAL", "idx": 1985, "val": 14427894.0}, {"col": "CHA", "idx": 1985, "val": 9846178.0}, {"col": "CHN", "idx": 1985, "val": 12702917.0}, {"col": "CIN", "idx": 1985, "val": 8359917.0}, {"col": "CLE", "idx": 1985, "val": 6551666.0}, {"col": "COL", "idx": 1985, "val": NaN}, {"col": "DET", "idx": 1985, "val": 10348143.0}, {"col": "FLO", "idx": 1985, "val": NaN}, {"col": "HOU", "idx": 1985, "val": 9993051.0}, {"col": "KCA", "idx": 1985, "val": 9321179.0}, {"col": "LAA", "idx": 1985, "val": NaN}, {"col": "LAN", "idx": 1985, "val": 10967917.0}, {"col": "MIA", "idx": 1985, "val": NaN}, {"col": "MIL", "idx": 1985, "val": NaN}, {"col": "MIN", "idx": 1985, "val": 5764821.0}, {"col": "ML4", "idx": 1985, "val": 11284107.0}, {"col": "MON", "idx": 1985, "val": 9470166.0}, {"col": "NYA", "idx": 1985, "val": 14238204.0}, {"col": "NYN", "idx": 1985, "val": 10834762.0}, {"col": "OAK", "idx": 1985, "val": 9058606.0}, {"col": "PHI", "idx": 1985, "val": 10124966.0}, {"col": "PIT", "idx": 1985, "val": 9227500.0}, {"col": "SDN", "idx": 1985, "val": 11036583.0}, {"col": "SEA", "idx": 1985, "val": 4613000.0}, {"col": "SFN", "idx": 1985, "val": 8221714.0}, {"col": "SLN", "idx": 1985, "val": 11817083.0}, {"col": "TBA", "idx": 1985, "val": NaN}, {"col": "TEX", "idx": 1985, "val": 7676500.0}, {"col": "TOR", "idx": 1985, "val": 8812550.0}, {"col": "WAS", "idx": 1985, "val": NaN}, {"col": "ANA", "idx": 1986, "val": NaN}, {"col": "ARI", "idx": 1986, "val": NaN}, {"col": "ATL", "idx": 1986, "val": 17102786.0}, {"col": "BAL", "idx": 1986, "val": 13001258.0}, {"col": "BOS", "idx": 1986, "val": 14402239.0}, {"col": "CAL", "idx": 1986, "val": 14427258.0}, {"col": "CHA", "idx": 1986, "val": 10418819.0}, {"col": "CHN", "idx": 1986, "val": 17208165.0}, {"col": "CIN", "idx": 1986, "val": 11906388.0}, {"col": "CLE", "idx": 1986, "val": 7809500.0}, {"col": "COL", "idx": 1986, "val": NaN}, {"col": "DET", "idx": 1986, "val": 12335714.0}, {"col": "FLO", "idx": 1986, "val": NaN}, {"col": "HOU", "idx": 1986, "val": 9873276.0}, {"col": "KCA", "idx": 1986, "val": 13043698.0}, {"col": "LAA", "idx": 1986, "val": NaN}, {"col": "LAN", "idx": 1986, "val": 14913776.0}, {"col": "MIA", "idx": 1986, "val": NaN}, {"col": "MIL", "idx": 1986, "val": NaN}, {"col": "MIN", "idx": 1986, "val": 8748167.0}, {"col": "ML4", "idx": 1986, "val": 9943642.0}, {"col": "MON", "idx": 1986, "val": 11103600.0}, {"col": "NYA", "idx": 1986, "val": 18494253.0}, {"col": "NYN", "idx": 1986, "val": 15393714.0}, {"col": "OAK", "idx": 1986, "val": 9779421.0}, {"col": "PHI", "idx": 1986, "val": 11590166.0}, {"col": "PIT", "idx": 1986, "val": 10843500.0}, {"col": "SDN", "idx": 1986, "val": 11380693.0}, {"col": "SEA", "idx": 1986, "val": 5958309.0}, {"col": "SFN", "idx": 1986, "val": 8947000.0}, {"col": "SLN", "idx": 1986, "val": 9875010.0}, {"col": "TBA", "idx": 1986, "val": NaN}, {"col": "TEX", "idx": 1986, "val": 6743119.0}, {"col": "TOR", "idx": 1986, "val": 12611047.0}, {"col": "WAS", "idx": 1986, "val": NaN}, {"col": "ANA", "idx": 1987, "val": NaN}, {"col": "ARI", "idx": 1987, "val": NaN}, {"col": "ATL", "idx": 1987, "val": 16544560.0}, {"col": "BAL", "idx": 1987, "val": 13900273.0}, {"col": "BOS", "idx": 1987, "val": 10144167.0}, {"col": "CAL", "idx": 1987, "val": 12843499.0}, {"col": "CHA", "idx": 1987, "val": 10641843.0}, {"col": "CHN", "idx": 1987, "val": 14307999.0}, {"col": "CIN", "idx": 1987, "val": 9281500.0}, {"col": "CLE", "idx": 1987, "val": 8513750.0}, {"col": "COL", "idx": 1987, "val": NaN}, {"col": "DET", "idx": 1987, "val": 12122881.0}, {"col": "FLO", "idx": 1987, "val": NaN}, {"col": "HOU", "idx": 1987, "val": 12608371.0}, {"col": "KCA", "id ...

# %% [markdown]
# <hr>

# %% [markdown]
# ## Exercises

# %% [markdown]
# #### Basic plotting

# %% [markdown]
# Plot the function $f(x) = x^3 - 2x^2 + 4$ on the domain $[-5, 5]$.

# %%
def func(x):
    return None  # replace None by your answer

domain = range(-5, 6)
# plt.plot(...  # replace by your answer

# %% [markdown]
# Let's get some arbitrary dataset (see below)

# %%
import numpy as np  # import numpy -- we will cover this later
N = 1000  # number of dots
x = np.random.random(N)  # get N random values between 0 and 1
df = pd.DataFrame(dict(
        A=x,
        B=func(x),
        C=func(x) / func(x - 1)))
df.head()

# %% [markdown]
# - Plot A against B, A against C, and B against C

# %% [markdown]
# - Plot A against B, and make the size of the dots correspond with C

# %% [markdown]
# - Plot B against C, and make the _color_ of the dots correspond with A. (This should result in a grey scale.)

# %% [markdown]
# #### Pandas plots

# %% [markdown]
# Load the Lahman baseball datasets.

# %%
# Loading the Baseball datasets
master = pd.read_csv(path_to_data + 'Master.csv')
batting = pd.read_csv(path_to_data + 'Batting.csv')
salaries = pd.read_csv(path_to_data + 'Salaries.csv')

# %% [markdown]
# - How does the average salary of baseball players increase over time?

# %% [markdown]
# In case you haven't done them already, complete teh visualizations exercises from the *Intro to Pandas* notebook.
#
# - Produce a histogram of player salaries.
# - Plot salary against a few statistics of the batting statistics (HR, RBI, R) - are any of these well-correlated?
#
# (Solutions are already given in the `into_to_pandas_solutions.ipynb` notebook of last class.)

# %%
# Loading the Baseball datasets
master = pd.read_csv(path_to_data + 'Master.csv')
batting = pd.read_csv(path_to_data + 'Batting.csv')
salaries = pd.read_csv(path_to_data + 'Salaries.csv')

# %%
# Solutions are already given in the `into_to_pandas_solutions.ipynb` notebook of last class.

# %% [markdown]
# ## Further reading

# %% [markdown]
# - <b>Pandas</b>:
# <a href="http://pandas.pydata.org/pandas-docs/stable/10min.html" target="_blank">10 Minutes to Pandas</a> and
# <a href="http://pandas.pydata.org/pandas-docs/stable/tutorials.html" target="_blank">tutorials</a>
# of the official documentation<br>
# Also recommended is the book <i>Python for Data Analysis</i>, O'Reilly Media.
# - <b>Matplotlib pyplot</b>:
# <a href="http://matplotlib.org/users/pyplot_tutorial.html" target="_blank">tutorial</a>
# of the official documentation
# - <b>Seaborn</b>:
# <a href="http://stanford.edu/~mwaskom/software/seaborn/" target="_blank">website</a>
